# %% [markdown]
# The Normal Equation

# %%
#Test the Normal Equation
import numpy as np

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X]
X_b
# Out:
# array([[1.00000000e+00, 1.01367040e+00],
#        [1.00000000e+00, 7.24313473e-02],
#        [1.00000000e+00, 4.82211789e-01],
#        [1.00000000e+00, 6.65541601e-01],
#        [1.00000000e+00, 1.53985362e+00],
#        [1.00000000e+00, 1.14288629e+00],
#        [1.00000000e+00, 1.26052897e+00],
#        [1.00000000e+00, 2.10832277e-02],
#        [1.00000000e+00, 1.86456918e+00],
#        [1.00000000e+00, 1.74716863e+00],
#        [1.00000000e+00, 1.36020354e-01],
#        [1.00000000e+00, 1.55802472e+00],
#        [1.00000000e+00, 1.10901227e+00],
#        [1.00000000e+00, 1.81854817e+00],
#        [1.00000000e+00, 1.85929817e+00],
#        [1.00000000e+00, 8.83406078e-01],
#        [1.00000000e+00, 1.65144081e+00],
#        [1.00000000e+00, 1.63749807e-01],
#        [1.00000000e+00, 1.17300462e+00],
#        [1.00000000e+00, 1.65669618e+00],
#        [1.00000000e+00, 2.73178898e-01],
#        [1.00000000e+00, 1.90435044e+00],
#        [1.00000000e+00, 1.52121017e+00],
#        [1.00000000e+00, 9.00056251e-01],
#        [1.00000000e+00, 1.21186495e-01],
#        [1.00000000e+00, 6.35732461e-01],
#        [1.00000000e+00, 1.27708846e+00],
#        [1.00000000e+00, 8.94032176e-01],
#        [1.00000000e+00, 3.71237777e-01],
#        [1.00000000e+00, 1.85432329e-01],
#        [1.00000000e+00, 1.76381858e+00],
#        [1.00000000e+00, 6.54303402e-01],
#        [1.00000000e+00, 3.99198631e-01],
#        [1.00000000e+00, 8.20295003e-01],
#        [1.00000000e+00, 1.13902301e+00],
#        [1.00000000e+00, 1.79574840e+00],
#        [1.00000000e+00, 1.43726629e+00],
#        [1.00000000e+00, 9.63526350e-01],
#        [1.00000000e+00, 8.37765569e-01],
#        [1.00000000e+00, 1.22556487e+00],
#        [1.00000000e+00, 1.38621963e+00],
#        [1.00000000e+00, 1.51603572e+00],
#        [1.00000000e+00, 1.89688004e+00],
#        [1.00000000e+00, 1.44177062e+00],
#        [1.00000000e+00, 8.16203603e-02],
#        [1.00000000e+00, 9.18409520e-01],
#        [1.00000000e+00, 1.37443756e+00],
#        [1.00000000e+00, 7.22062563e-01],
#        [1.00000000e+00, 1.83307260e+00],
#        [1.00000000e+00, 1.25939878e+00],
#        [1.00000000e+00, 6.39079340e-01],
#        [1.00000000e+00, 6.30201976e-01],
#        [1.00000000e+00, 2.00680672e-01],
#        [1.00000000e+00, 1.20433734e+00],
#        [1.00000000e+00, 1.47514932e+00],
#        [1.00000000e+00, 8.19713108e-04],
#        [1.00000000e+00, 2.69635171e-01],
#        [1.00000000e+00, 1.63849948e+00],
#        [1.00000000e+00, 1.22943821e+00],
#        [1.00000000e+00, 1.77082676e-01],
#        [1.00000000e+00, 1.23138942e+00],
#        [1.00000000e+00, 1.01380045e+00],
#        [1.00000000e+00, 1.71514811e+00],
#        [1.00000000e+00, 1.60515189e-01],
#        [1.00000000e+00, 4.46146218e-01],
#        [1.00000000e+00, 1.05093418e+00],
#        [1.00000000e+00, 1.29525328e+00],
#        [1.00000000e+00, 1.93870112e+00],
#        [1.00000000e+00, 1.81718500e+00],
#        [1.00000000e+00, 1.56416613e+00],
#        [1.00000000e+00, 6.26311008e-01],
#        [1.00000000e+00, 1.01682818e+00],
#        [1.00000000e+00, 1.59054229e+00],
#        [1.00000000e+00, 8.49532022e-01],
#        [1.00000000e+00, 1.08295613e-01],
#        [1.00000000e+00, 7.06462209e-01],
#        [1.00000000e+00, 1.10603015e+00],
#        [1.00000000e+00, 7.24208316e-01],
#        [1.00000000e+00, 1.84478219e+00],
#        [1.00000000e+00, 1.07476609e+00],
#        [1.00000000e+00, 9.33821790e-01],
#        [1.00000000e+00, 1.95450531e-01],
#        [1.00000000e+00, 4.45705135e-03],
#        [1.00000000e+00, 1.10331177e-01],
#        [1.00000000e+00, 8.46242914e-01],
#        [1.00000000e+00, 1.17348988e+00],
#        [1.00000000e+00, 1.18905433e+00],
#        [1.00000000e+00, 9.33189165e-01],
#        [1.00000000e+00, 2.64710611e-01],
#        [1.00000000e+00, 8.52727316e-01],
#        [1.00000000e+00, 1.22850544e+00],
#        [1.00000000e+00, 1.66647496e-01],
#        [1.00000000e+00, 1.11956019e+00],
#        [1.00000000e+00, 2.64296158e-01],
#        [1.00000000e+00, 2.96802409e-01],
#        [1.00000000e+00, 9.57275058e-01],
#        [1.00000000e+00, 7.06613017e-01],
#        [1.00000000e+00, 1.39350710e+00],
#        [1.00000000e+00, 1.43655412e-01],
#        [1.00000000e+00, 1.81929104e+00]])

# %%
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best
# Out:
# array([[3.93377877],
#        [3.07635052]])

# %%
X_new = np.array([[0], [2]])
X_new
# Out:
# array([[0],
#        [2]])

# %%
X_new_b = np.c_[np.ones((2, 1)), X_new]
X_new_b
# Out:
# array([[1., 0.],
#        [1., 2.]])

# %%
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 3.93377877],
#        [10.08647982]])

# %%
plt.plot(X_new, y_predict, 'r-', label='Predictions')
plt.plot(X, y, 'b.')
plt.axis([0, 2, 0, 15])
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
